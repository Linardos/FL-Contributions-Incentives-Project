# %% [markdown]
# <a href="https://colab.research.google.com/github/vs-152/FL-Contributions-Incentives-Project/blob/main/ISO_CIFAR10_MR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import numpy as np
# !pip install pulp
import pulp
import copy
import time
from sklearn.model_selection import StratifiedShuffleSplit
import torchvision
from torchvision.datasets import CIFAR10
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.utils.data.sampler import SubsetRandomSampler
from itertools import chain, combinations
from tqdm import tqdm
from scipy.special import comb
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.7/dist-packages (2.4)
# Requirement already satisfied: amply>=0.1.2 in /usr/local/lib/python3.7/dist-packages (from pulp) (0.1.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from amply>=0.1.2->pulp) (2.4.7)
# Requirement already satisfied: docutils>=0.3 in /usr/local/lib/python3.7/dist-packages (from amply>=0.1.2->pulp) (0.17)

# %%
def print_solution(model):
    """Prints solution of the model nicely!"""

    print(f"status: {model.status}, {pulp.LpStatus[model.status]}")
    print(f"objective: {model.objective.value()}")
    for var in model.variables():
        print(f"{var.name}: {round(var.value(),3)}")

def noisify_MNIST(noise_rate, noise_type, x, y, perm=[], **kwargs):
    '''Returns a symmetrically noisy dataset
    or a an asymmetrically noisy dataset with permutation matrix perm.
    '''
    if (noise_rate == 0.):
        return y, []
    if 'seed' in kwargs:
        _, noise_idx = next(
            iter(StratifiedShuffleSplit(
                n_splits=1,
                test_size=noise_rate,
                random_state=kwargs['seed']).split(x, y)))
    else:
        _, noise_idx = next(iter(StratifiedShuffleSplit(
            n_splits=1, test_size=noise_rate).split(x, y)))
    y_noisy = y.copy()
    if (noise_type == 'symmetric'):
        for i in noise_idx:
            t1 = np.arange(10)
            t2 = np.delete(t1, y[i])
            y_noisy[i] = np.random.choice(t2, 1)
    elif (noise_type == 'asymmetric'):
        pure_noise = perm[y]
        for i in noise_idx:
            if (perm[y[i]] == y[i]):
                noise_idx = np.delete(noise_idx, np.where(noise_idx == i))
            else:
                y_noisy[i] = pure_noise[i]

    return y_noisy, noise_idx

def mnist_iid(dataset, num_users):
    """
    Sample I.I.D. client data from MNIST dataset
    :param dataset:
    :param num_users:
    :return: dict of image index
    """
    num_items = int(len(dataset)/num_users)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items,
                                             replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])

    return dict_users

def average_weights(w, fraction):  # this can also be used to average gradients
    """
    :param w: list of weights generated from the users
    :param fraction: list of fraction of data from the users
    :Returns the weighted average of the weights.
    """
    w_avg = copy.deepcopy(w[0]) #copy the weights from the first user in the list 
    for key in w_avg.keys():
        w_avg[key] *= torch.tensor(fraction[0]/sum(fraction), dtype=w_avg[key].dtype)
        for i in range(1, len(w)):
            w_avg[key] += w[i][key] * torch.tensor(fraction[0]/sum(fraction), dtype=w_avg[key].dtype)

    return w_avg

def calculate_gradients(new_weights, old_weights):
    """
    :param new_weights: list of weights generated from the users
    :param old_weights: old weights of a model, probably before training
    :Returns the list of gradients.
    """
    gradients = []
    for i in range(len(new_weights)):
        gradients.append(copy.deepcopy(new_weights[i]))
        for key in gradients[i].keys():
            gradients[i][key] -= old_weights[key]

    return gradients

def update_weights_from_gradients(gradients, old_weights):
    """
    :param gradients: gradients
    :param old_weights: old weights of a model, probably before training
    :Returns the updated weights calculated by: old_weights+gradients.
    """
    updated_weights = copy.deepcopy(old_weights)
    for key in updated_weights.keys():
        updated_weights[key] = old_weights[key] + gradients[key]

    return updated_weights
    


def powersettool(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

def least_core(char_function_dict, N):
    """Solves the least core LP problem.

    Args:
        N: number of participants.
        char_function_dict: dictionary with participants as keys and 
        corresponding characteristic function value as values
    """
    model = pulp.LpProblem('least_core', pulp.LpMinimize)
    x = {i: pulp.LpVariable(name=f'x({i})', lowBound=0) for i in range(1, N+1)}
    e = pulp.LpVariable(name='e')
    model += e # decision variable
    grand_coalition = tuple(i for i in range(1, N+1))
    model += pulp.lpSum(x) == char_function_dict[grand_coalition]
    for key, value in char_function_dict.items():
        model += pulp.lpSum(x[idx] for idx in key) + e >= value
    model.solve()
    print_solution(model)

    return model

def shapley(utility, N):

    shapley_dict = {}
    for i in range(1, N+1):
        shapley_dict[i] = 0
    for key in utility:
        if key != ():
            for contributor in key:
                # print('contributor:', contributor, key) # print check
                marginal_contribution = utility[key] - utility[tuple(i for i in key if i!=contributor)]
                # print('marginal:', marginal_contribution) # print check
                shapley_dict[contributor] += marginal_contribution /((comb(N-1,len(key)-1))*N)

    return shapley_dict

# %%
transform_train = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomCrop(32, padding=4),
    #transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    #transforms.RandomErasing(scale=(0.1, 0.3), ratio=(0.5, 2), value=0)
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = CIFAR10(
    root='./data', train=True, download=True)

test_dataset = CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)

x_train = trainset.data
y_train = np.array(trainset.targets)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class ResNet9(nn.Module):
    def __init__(self):
        super(ResNet9, self).__init__()
        self.prep = self.convbnrelu(channels=3, filters=64)
        self.layer1 = self.convbnrelu(64, 128)
        self.layer_pool = nn.MaxPool2d(2, 2, 0, 1, ceil_mode=False)
        self.layer1r1 = self.convbnrelu(128, 128)
        self.layer1r2 = self.convbnrelu(128, 128)
        self.layer2 = self.convbnrelu(128, 256)
        self.layer3 = self.convbnrelu(256, 512)
        self.layer3r1 = self.convbnrelu(512, 512)
        self.layer3r2 = self.convbnrelu(512, 512)
        self.out_pool = nn.MaxPool2d(kernel_size=4, stride=4, ceil_mode=False)
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(in_features=512, out_features=10, bias=False)

    def convbnrelu(self, channels, filters):
        layers = []
        layers.append(nn.Conv2d(channels, filters, (3, 3),
                                (1, 1), (1, 1), bias=False))
        layers.append(nn.BatchNorm2d(filters, track_running_stats=False))
        layers.append(nn.ReLU(inplace=True))

        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.prep(x)
        x = self.layer_pool(self.layer1(x))
        r1 = self.layer1r2(self.layer1r1(x)) 
        x = x + r1
        x = self.layer_pool(self.layer2(x))
        x = self.layer_pool(self.layer3(x))
        r3 = self.layer3r2(self.layer3r1(x))
        x = x + r3
        out = self.out_pool(x)
        out = self.flatten(out)
        out = self.linear(out)
        out = out * 0.125

        return out

class CustomTensorDataset(Dataset):
    """TensorDataset with support of transforms.
    """
    def __init__(self, tensors, transform=None):
        self.tensors = tensors
        self.transform = transform

    def __getitem__(self, index):
        x = self.tensors[0][index]

        if self.transform:
            x = self.transform(x)

        y = self.tensors[1][index]

        return x, y

    def __len__(self):
        return self.tensors[0].shape[0]

# %%
class LocalUpdate(object):

    def __init__(self, lr, local_ep, trainloader):
        self.lr = lr
        self.local_ep = local_ep
        self.trainloader = trainloader

    def update_weights(self, model):

        model.train()
        epoch_loss = []
        optimizer = torch.optim.Adam(model.parameters())
        criterion = nn.CrossEntropyLoss().to(device)
        for iter in range(self.local_ep):
            batch_loss = []
            for batch_idx, (images, labels) in enumerate(self.trainloader):
                images, labels = images.to(device), labels.to(device)
                model.zero_grad()   
                log_probs = model(images)
                loss = criterion(log_probs, labels)
                loss.backward()
                optimizer.step()
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))

        return model.state_dict(), sum(epoch_loss) / len(epoch_loss)

def test_inference(model, test_dataset):

    model.eval()
    loss, total, correct = 0.0, 0.0, 0.0
    criterion = nn.CrossEntropyLoss().to(device)
    testloader = DataLoader(test_dataset, batch_size=200, shuffle=False)

    for _, (images, labels) in enumerate(testloader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        batch_loss = criterion(outputs, labels)
        loss += batch_loss.item()
        _, pred_labels = torch.max(outputs, 1)
        pred_labels = pred_labels.view(-1)
        correct += torch.sum(torch.eq(pred_labels, labels)).item()
        total += len(labels)
    accuracy = correct / total

    return accuracy, loss

# %%
N = 8 #srch
local_bs = 512
lr = 0.01
local_ep = 5
EPOCHS = 5

noise_rates = np.linspace(0, 1, N, endpoint=False)
split_dset = mnist_iid(trainset, N)
user_groups = {i: 0 for i in range(1, N+1)}
noise_idx = {i: 0 for i in range(1, N+1)}
train_datasets = {i: 0 for i in range(1, N+1)}
for n in range(N):
    user_groups[n+1] = np.array(list(split_dset[n]), dtype=np.int)
    user_train_x, user_train_y = x_train[user_groups[n+1]], y_train[user_groups[n+1]]
    user_noisy_y, noise_idx[n+1] = noisify_MNIST(noise_rates[n], 'symmetric', user_train_x, user_train_y)
    
    train_datasets[n+1] = CustomTensorDataset((user_train_x, user_noisy_y), transform_train)

def fixfuckingbn(subset_weights, global_model_state_dict):
    for pair_1, pair_2 in zip(subset_weights.items(), global_model_state_dict.items()):
        if ('running' in pair_1[0]) or ('batches' in pair_1[0]):
            subset_weights[pair_1[0]] = global_model_state_dict[pair_1[0]]
    
    return subset_weights

global_model = ResNet9().to(device)
global_model.to(device)
global_model.train()

global_weights = global_model.state_dict()
powerset = list(powersettool(range(1, N+1)))

submodel_dict = {}  
submodel_dict[()] = copy.deepcopy(global_model)
accuracy_dict = {}
shapley_dict = {}

# %%
start_time = time.time()

for subset in powerset[:-1]: #exclude only the global set. the null set still has a random initialized model
    submodel_dict[subset] = copy.deepcopy(global_model)
    submodel_dict[subset].to(device)
    submodel_dict[subset].train()
 
train_loss, train_accuracy = [], []
val_acc_list, net_list = [], []
print_every = 1

idxs_users = np.arange(1, N+1)
total_data = sum(len(user_groups[i]) for i in range(1, N+1))
fraction = [len(user_groups[i])/total_data for i in range(1, N+1)]

for epoch in tqdm(range(EPOCHS)):
    local_weights, local_losses = [], []
    print(f'\n | Global Training Round : {epoch+1} |\n')
    global_model.train()
    for idx in idxs_users:
        trainloader = DataLoader(train_datasets[idx], batch_size=local_bs, shuffle=True)
        local_model = LocalUpdate(lr, local_ep, trainloader)
        w, loss = local_model.update_weights(model=copy.deepcopy(global_model))
        local_weights.append(copy.deepcopy(w))
        local_losses.append(copy.deepcopy(loss))
    global_weights = average_weights(local_weights, fraction) 
    loss_avg = sum(local_losses) / len(local_losses)
    train_loss.append(loss_avg)

    gradients = calculate_gradients(local_weights, global_model.state_dict())

    for subset in powerset[1: -1]: 
        subset_gradient = average_weights([gradients[i-1] for i in subset], [fraction[i-1] for i in subset])
        subset_weights = update_weights_from_gradients(subset_gradient, submodel_dict[subset].state_dict())
        submodel_dict[subset].load_state_dict(subset_weights)

    global_model.load_state_dict(global_weights)
    global_model.eval()

    if (epoch+1) % print_every == 0:
        print(f' \nAvg Training Stats after {epoch+1} global rounds:')
        print(f'Training Loss : {np.mean(np.array(train_loss))}')
        # print('Train Accuracy: {:.2f}% \n'.format(100*train_accuracy[-1]))

    accuracy_dict[powerset[-1]] = test_inference(global_model, test_dataset)[0]

        # Test inference for the sub-models in submodel_dict
    for subset in powerset[:-1]: 
        test_acc, test_loss = test_inference(submodel_dict[subset], test_dataset)
        print(f' \n Results after {epoch} global rounds of training:')
        print("|---- Test Accuracy for {}: {:.2f}%".format(subset, 100*test_acc))
            
        accuracy_dict[subset] = test_acc

    shapley_dict_add = shapley(accuracy_dict, N)
    for key in shapley_dict_add:
        if shapley_dict.get(key):
            shapley_dict[key].append(shapley_dict_add[key])
        else:
            shapley_dict[key] = [shapley_dict_add[key]]
test_acc, test_loss = test_inference(global_model, test_dataset)
print(f' \n Results after {EPOCHS} global rounds of training:')
print("|---- Test Accuracy: {:.2f}%".format(100*test_acc))

accuracy_dict[powerset[-1]] = test_acc


trainTime = time.time() - start_time
print('\n Total Time: {0:0.4f}'.format(trainTime))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  | Global Training Round : 1 |
#
#
# Avg Training Stats after 1 global rounds:
# Training Loss : 2.029203211344205
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (): 9.55%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1,): 56.65%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (2,): 55.97%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (3,): 51.76%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (4,): 47.53%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (5,): 44.68%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (6,): 38.06%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (7,): 25.25%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (8,): 12.35%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 2): 56.26%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 3): 53.65%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 4): 50.29%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 5): 51.12%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 6): 44.71%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 7): 39.19%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 8): 29.43%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (2, 3): 54.35%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (2, 4): 50.50%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (2, 5): 49.89%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (2, 6): 46.58%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (2, 7): 39.55%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (2, 8): 29.65%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (3, 4): 48.82%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (3, 5): 48.64%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (3, 6): 44.73%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (3, 7): 38.98%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (3, 8): 27.95%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (4, 5): 45.88%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (4, 6): 42.13%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (4, 7): 36.03%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (4, 8): 27.79%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (5, 6): 42.14%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (5, 7): 37.76%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (5, 8): 23.48%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (6, 7): 34.25%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (6, 8): 24.40%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (7, 8): 18.07%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 2, 3): 53.85%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 2, 4): 51.54%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 2, 5): 52.21%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 2, 6): 49.38%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 2, 7): 46.61%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 2, 8): 48.15%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 3, 4): 49.88%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 3, 5): 50.16%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 3, 6): 46.80%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 3, 7): 44.98%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 3, 8): 47.01%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 4, 5): 48.11%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 4, 6): 45.37%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 4, 7): 43.29%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 4, 8): 44.05%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 5, 6): 45.79%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 5, 7): 43.93%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 5, 8): 43.17%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 6, 7): 39.22%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1, 6, 8): 39.97%
#
#  Results after 0 global rounds of training:
# |---- Test Accuracy for (1,

#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 5, 6, 7): 52.38%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 5, 6, 8): 48.59%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 5, 7, 8): 45.26%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 6, 7, 8): 41.55%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 4, 5, 6, 7): 52.04%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 4, 5, 6, 8): 46.75%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 4, 5, 7, 8): 44.17%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 4, 6, 7, 8): 40.77%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 5, 6, 7, 8): 40.13%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 6): 56.60%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 7): 55.36%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 8): 52.23%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 6, 7): 53.26%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 6, 8): 47.79%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 7, 8): 47.04%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 5, 6, 7): 52.33%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 5, 6, 8): 47.98%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 5, 7, 8): 45.73%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 6, 7, 8): 42.18%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 4, 5, 6, 7): 51.95%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 4, 5, 6, 8): 46.47%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 4, 5, 7, 8): 45.65%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 4, 6, 7, 8): 42.54%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 5, 6, 7, 8): 40.57%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (3, 4, 5, 6, 7): 51.22%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (3, 4, 5, 6, 8): 47.08%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (3, 4, 5, 7, 8): 45.69%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (3, 4, 6, 7, 8): 41.88%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (3, 5, 6, 7, 8): 39.29%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (4, 5, 6, 7, 8): 41.22%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6): 57.86%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 7): 57.24%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 8): 55.09%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 6, 7): 55.74%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 6, 8): 53.23%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 7, 8): 51.73%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 5, 6, 7): 55.40%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 5, 6, 8): 52.47%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 5, 7, 8): 51.14%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 6, 7, 8): 48.25%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7): 54.76%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 5, 6, 8): 51.43%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 5, 7, 8): 50.32%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 6, 7, 8): 47.97%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 5, 6, 7, 8): 46.63%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7): 54.29%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 5, 6, 8): 51.99%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 5, 7, 8): 50.05%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 6, 7, 8): 47.27%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 5, 6, 7, 8): 46.38%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 4, 5, 6, 7, 8): 46.39%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7): 54.22%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 6, 8): 51.20%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 7, 8): 50.54%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 6, 7, 8): 47.79%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 5, 6, 7, 8): 46.45%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 4, 5, 6, 7, 8): 46.61%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (3, 4, 5, 6, 7, 8): 46.44%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 7): 56.13%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 8): 54.35%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 7, 8): 53.62%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 6, 7, 8): 51.57%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 5, 6, 7, 8): 50.48%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 8): 50.23%
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 8): 49.90%
#  40%|████      | 2/5 [41:28<1:02:15, 1245.33s/it]
#
#  Results after 1 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 8): 50.22%
#
#  | Global Training Round : 3 |
#
#
# Avg Training Stats after 3 global rounds:
# Training Loss : 1.9313873177919632
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (): 9.55%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (1,): 52.54%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (2,): 50.33%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (3,): 54.07%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (4,): 45.93%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (5,): 41.53%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (6,): 32.80%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (7,): 18.61%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (8,): 13.09%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (1, 2): 57.75%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (1, 3): 59.24%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (1, 4): 57.55%
#
#  Results after 2 global rounds of training:
# |---- Test Accuracy for (1, 5): 58.42%
#
# ...
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (4, 5, 8): 9.47%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for

#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (3, 4, 5, 7, 8): 27.20%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (3, 4, 6, 7, 8): 24.88%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (3, 5, 6, 7, 8): 19.98%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (4, 5, 6, 7, 8): 18.18%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6): 59.95%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 7): 63.98%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 8): 60.91%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 6, 7): 63.83%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 6, 8): 57.74%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 7, 8): 50.14%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 5, 6, 7): 64.36%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 5, 6, 8): 60.01%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 5, 7, 8): 52.75%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 6, 7, 8): 52.04%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7): 62.48%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 5, 6, 8): 57.38%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 5, 7, 8): 49.17%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 6, 7, 8): 49.73%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 5, 6, 7, 8): 48.76%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7): 62.49%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 5, 6, 8): 56.43%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 5, 7, 8): 48.00%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 6, 7, 8): 47.72%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 3, 5, 6, 7, 8): 47.76%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 4, 5, 6, 7, 8): 43.71%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7): 61.98%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 6, 8): 56.03%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 7, 8): 49.01%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 6, 7, 8): 46.29%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (2, 3, 5, 6, 7, 8): 46.81%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (2, 4, 5, 6, 7, 8): 44.05%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (3, 4, 5, 6, 7, 8): 36.74%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 7): 64.74%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 8): 66.01%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 5, 7, 8): 61.23%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 4, 6, 7, 8): 61.96%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 3, 5, 6, 7, 8): 61.79%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 8): 59.54%
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 8): 58.65%
# 100%|██████████| 5/5 [1:42:43<00:00, 1232.77s/it]
#
#  Results after 4 global rounds of training:
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 8): 58.54%
#
#  Results after 5 global rounds of training:
# |---- Test Accuracy: 67.04%
#
#  Total Time: 6169.5254

# %%
def stats(vector):
    n = len(vector)
    egal = np.array([1/n for i in range(n)])
    normalised = np.array(vector / vector.sum())
    msg = f'Original vector: {vector}\n'
    msg += f'Normalised vector: {normalised}\n'
    msg += f'Max Dif: {normalised.max()-normalised.min()}\n'
    msg += f'Distance: {np.linalg.norm(normalised-egal)}\n'

    msg += f'Budget: {vector.sum()}\n'
    print(msg)

# %%
fedshap = {i: 0 for i in range(1, N+1)}
lambdamr = {i: 0 for i in range(1, N+1)}
decay = [0.8**t for t in range(EPOCHS)]

epoch_sums = []
for i in range(EPOCHS):
    epoch_sums.append(sum([v[i] for k,v in shapley_dict.items()]))

for key, values in shapley_dict.items():

    for i, v in enumerate(values):
        lambdamr[key] += v * decay[i]/epoch_sums[i]
    fedshap[key] = sum(values)

# %%
stats(np.array([i for i in lambdamr.values()]))
# Out:
# Original vector: [ 0.8659393   0.86673934  0.81142407  0.64265102  0.56302027  0.3289211
#  -0.04089612 -0.67619899]
# Normalised vector: [ 0.25759736  0.25783536  0.24138032  0.19117415  0.1674858   0.09784659
#  -0.01216567 -0.20115391]
# Max Dif: 0.4589892692452328
# Distance: 0.4253044043561356
# Budget: 3.3616

# %%
stats(np.array([i for i in fedshap.values()]))
# Out:
# Original vector: [ 0.61085976  0.59703929  0.58528714  0.46891905  0.40049214  0.25737667
#   0.00533595 -0.52891   ]
# Normalised vector: [ 0.25490726  0.24914008  0.244236    0.19567645  0.16712241  0.10740138
#   0.00222665 -0.22071023]
# Max Dif: 0.4756174937008687
# Distance: 0.4337878600975636
# Budget: 2.3964
