# %% [markdown]
# <a href="https://colab.research.google.com/github/vs-152/FL-Contributions-Incentives-Project/blob/main/ISO_CIFAR10_OR_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import numpy as np
# !pip install pulp
import pulp
import copy
import time
from sklearn.model_selection import StratifiedShuffleSplit
import torchvision
from torchvision.datasets import CIFAR10
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.utils.data.sampler import SubsetRandomSampler
from itertools import chain, combinations
from tqdm import tqdm
from scipy.special import comb
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Requirement already satisfied: pulp in /home/locolinux2/miniconda3/envs/m_quant/lib/python3.9/site-packages (3.1.1)

# %%
def print_solution(model):
    """Prints solution of the model nicely!"""

    print(f"status: {model.status}, {pulp.LpStatus[model.status]}")
    print(f"objective: {model.objective.value()}")
    for var in model.variables():
        print(f"{var.name}: {round(var.value(),3)}")

def noisify_MNIST(noise_rate, noise_type, x, y, perm=[], **kwargs):
    '''Returns a symmetrically noisy dataset
    or a an asymmetrically noisy dataset with permutation matrix perm.
    '''
    if (noise_rate == 0.):
        return y, []
    if 'seed' in kwargs:
        _, noise_idx = next(
            iter(StratifiedShuffleSplit(
                n_splits=1,
                test_size=noise_rate,
                random_state=kwargs['seed']).split(x, y)))
    else:
        _, noise_idx = next(iter(StratifiedShuffleSplit(
            n_splits=1, test_size=noise_rate).split(x, y)))
    y_noisy = y.copy()
    if (noise_type == 'symmetric'):
        for i in noise_idx:
            t1 = np.arange(10)
            t2 = np.delete(t1, y[i])
            y_noisy[i] = np.random.choice(t2, 1)
    elif (noise_type == 'asymmetric'):
        pure_noise = perm[y]
        for i in noise_idx:
            if (perm[y[i]] == y[i]):
                noise_idx = np.delete(noise_idx, np.where(noise_idx == i))
            else:
                y_noisy[i] = pure_noise[i]

    return y_noisy, noise_idx

def mnist_iid(dataset, num_users):
    """
    Sample I.I.D. client data from MNIST dataset
    :param dataset:
    :param num_users:
    :return: dict of image index
    """
    num_items = int(len(dataset)/num_users)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items,
                                             replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])

    return dict_users

def average_weights(w, fraction):  # this can also be used to average gradients
    """
    :param w: list of weights generated from the users
    :param fraction: list of fraction of data from the users
    :Returns the weighted average of the weights.
    """
    w_avg = copy.deepcopy(w[0]) #copy the weights from the first user in the list 
    for key in w_avg.keys():
        w_avg[key] *= torch.tensor(fraction[0]/sum(fraction), dtype=w_avg[key].dtype)
        for i in range(1, len(w)):
            w_avg[key] += w[i][key] * torch.tensor(fraction[0]/sum(fraction), dtype=w_avg[key].dtype)

    return w_avg

def calculate_gradients(new_weights, old_weights):
    """
    :param new_weights: list of weights generated from the users
    :param old_weights: old weights of a model, probably before training
    :Returns the list of gradients.
    """
    gradients = []
    for i in range(len(new_weights)):
        gradients.append(copy.deepcopy(new_weights[i]))
        for key in gradients[i].keys():
            gradients[i][key] -= old_weights[key]

    return gradients

def update_weights_from_gradients(gradients, old_weights):
    """
    :param gradients: gradients
    :param old_weights: old weights of a model, probably before training
    :Returns the updated weights calculated by: old_weights+gradients.
    """
    updated_weights = copy.deepcopy(old_weights)
    for key in updated_weights.keys():
        updated_weights[key] = old_weights[key] + gradients[key]

    return updated_weights
    


def powersettool(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

def least_core(char_function_dict, N):
    """Solves the least core LP problem.

    Args:
        N: number of participants.
        char_function_dict: dictionary with participants as keys and 
        corresponding characteristic function value as values
    """
    model = pulp.LpProblem('least_core', pulp.LpMinimize)
    x = {i: pulp.LpVariable(name=f'x({i})', lowBound=0) for i in range(1, N+1)}
    e = pulp.LpVariable(name='e')
    model += e # decision variable
    grand_coalition = tuple(i for i in range(1, N+1))
    model += pulp.lpSum(x) == char_function_dict[grand_coalition]
    for key, value in char_function_dict.items():
        model += pulp.lpSum(x[idx] for idx in key) + e >= value
    model.solve()
    print_solution(model)

    return model

def shapley(utility, N):

    shapley_dict = {}
    for i in range(1, N+1):
        shapley_dict[i] = 0
    for key in utility:
        if key != ():
            for contributor in key:
                # print('contributor:', contributor, key) # print check
                marginal_contribution = utility[key] - utility[tuple(i for i in key if i!=contributor)]
                # print('marginal:', marginal_contribution) # print check
                shapley_dict[contributor] += marginal_contribution /((comb(N-1,len(key)-1))*N)

    return shapley_dict

# %%
transform_train = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomCrop(32, padding=4),
    #transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    #transforms.RandomErasing(scale=(0.1, 0.3), ratio=(0.5, 2), value=0)
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = CIFAR10(
    root='./data', train=True, download=True)

test_dataset = CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)

x_train = trainset.data
y_train = np.array(trainset.targets)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class ResNet9(nn.Module):
    def __init__(self):
        super(ResNet9, self).__init__()
        self.prep = self.convbnrelu(channels=3, filters=64)
        self.layer1 = self.convbnrelu(64, 128)
        self.layer_pool = nn.MaxPool2d(2, 2, 0, 1, ceil_mode=False)
        self.layer1r1 = self.convbnrelu(128, 128)
        self.layer1r2 = self.convbnrelu(128, 128)
        self.layer2 = self.convbnrelu(128, 256)
        self.layer3 = self.convbnrelu(256, 512)
        self.layer3r1 = self.convbnrelu(512, 512)
        self.layer3r2 = self.convbnrelu(512, 512)
        self.out_pool = nn.MaxPool2d(kernel_size=4, stride=4, ceil_mode=False)
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(in_features=512, out_features=10, bias=False)

    def convbnrelu(self, channels, filters):
        layers = []
        layers.append(nn.Conv2d(channels, filters, (3, 3),
                                (1, 1), (1, 1), bias=False))
        layers.append(nn.BatchNorm2d(filters, track_running_stats=False))
        layers.append(nn.ReLU(inplace=True))

        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.prep(x)
        x = self.layer_pool(self.layer1(x))
        r1 = self.layer1r2(self.layer1r1(x)) 
        x = x + r1
        x = self.layer_pool(self.layer2(x))
        x = self.layer_pool(self.layer3(x))
        r3 = self.layer3r2(self.layer3r1(x))
        x = x + r3
        out = self.out_pool(x)
        out = self.flatten(out)
        out = self.linear(out)
        out = out * 0.125

        return out

class CustomTensorDataset(Dataset):
    """TensorDataset with support of transforms.
    """
    def __init__(self, tensors, transform=None):
        self.tensors = tensors
        self.transform = transform

    def __getitem__(self, index):
        x = self.tensors[0][index]

        if self.transform:
            x = self.transform(x)

        y = self.tensors[1][index]

        return x, y

    def __len__(self):
        return self.tensors[0].shape[0]

# %%
class LocalUpdate(object):

    def __init__(self, lr, local_ep, trainloader):
        self.lr = lr
        self.local_ep = local_ep
        self.trainloader = trainloader

    def update_weights(self, model):

        model.train()
        epoch_loss = []
        optimizer = torch.optim.Adam(model.parameters())
        criterion = nn.CrossEntropyLoss().to(device)
        for iter in range(self.local_ep):
            batch_loss = []
            for batch_idx, (images, labels) in enumerate(self.trainloader):
                images, labels = images.to(device), labels.to(device)
                model.zero_grad()   
                log_probs = model(images)
                loss = criterion(log_probs, labels)
                loss.backward()
                optimizer.step()
                batch_loss.append(loss.item())
            epoch_loss.append(sum(batch_loss)/len(batch_loss))

        return model.state_dict(), sum(epoch_loss) / len(epoch_loss)

def test_inference(model, test_dataset):
    """
    Computes mean Dice across the three BraTS channels
    (whole tumour, tumour-core, enhancing-core).

    Returns
    -------
    float   ─ mean Dice in the range [0, 1]
    """
    model.eval()
    loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

    dice_sum = torch.zeros(3, device=device)   # accumulate per-class Dice
    n_batches = 0

    with torch.no_grad():
        for batch in loader:
            # ---- image tensor ------------------------------------------------
            img = torch.cat([batch[k] for k in ("flair", "t1", "t1ce", "t2")],
                            dim=1).to(device)                     # (B,4,D,H,W)

            # ---- ground-truth mask → one-hot (B,3,D,H,W) ---------------------
            raw    = batch["seg"].squeeze(1).cpu().numpy()       # (B,D,H,W)
            target = torch.tensor(
                        preprocess_mask_labels(raw),
                        dtype=torch.float32, device=device
                     )

            # ---- network prediction → one-hot (B,3,D,H,W) --------------------
            logits  = model(img)                                 # (B,3,D,H,W)
            pred_ch = torch.argmax(logits, dim=1)                # (B,D,H,W)
            pred    = torch.nn.functional.one_hot(
                          pred_ch, num_classes=3
                      ).permute(0,4,1,2,3).float()

            # ---- per-class Dice ---------------------------------------------
            intersect = 2 * (pred * target).sum(dim=(2,3,4))     # (B,3)
            denom     = (pred + target).sum(dim=(2,3,4)) + 1e-6
            dice_sum += (intersect / denom).squeeze(0)           # add (3,)
            n_batches += 1

    return (dice_sum / n_batches).mean().item()                  # scalar Dice

# %%
N = 10 #srch
local_bs = 512
lr = 0.01
local_ep = 5
EPOCHS = 5

noise_rates = np.linspace(0, 1, N, endpoint=False)
split_dset = mnist_iid(trainset, N)
user_groups = {i: 0 for i in range(1, N+1)}
noise_idx = {i: 0 for i in range(1, N+1)}
train_datasets = {i: 0 for i in range(1, N+1)}
for n in range(N):
    user_groups[n+1] = np.array(list(split_dset[n]), dtype=np.int32)
    user_train_x, user_train_y = x_train[user_groups[n+1]], y_train[user_groups[n+1]]
    user_noisy_y, noise_idx[n+1] = noisify_MNIST(noise_rates[n], 'symmetric', user_train_x, user_train_y)
    
    train_datasets[n+1] = CustomTensorDataset((user_train_x, user_noisy_y), transform_train)

def fixfuckingbn(subset_weights, global_model_state_dict):
    for pair_1, pair_2 in zip(subset_weights.items(), global_model_state_dict.items()):
        if ('running' in pair_1[0]) or ('batches' in pair_1[0]):
            subset_weights[pair_1[0]] = global_model_state_dict[pair_1[0]]
    
    return subset_weights

global_model = ResNet9().to(device)
global_model.to(device)
global_model.train()

global_weights = global_model.state_dict()
powerset = list(powersettool(range(1, N+1)))
submodel_dict = {}  
submodel_dict[()] = copy.deepcopy(global_model)
accuracy_dict = {}
shapley_dict = {}

# %%
user_groups
# Out:
# {1: array([    6, 32782, 32784, ..., 32753, 32754, 32759], dtype=int32),
#  2: array([32779, 32780,    13, ..., 32748, 32761, 32767], dtype=int32),
#  3: array([    1,    18, 32788, ..., 32742, 32747, 32763], dtype=int32),
#  4: array([32770, 32777,    34, ..., 32733, 32745, 32756], dtype=int32),
#  5: array([    0, 32769, 32778, ..., 32751, 32760, 32766], dtype=int32),
#  6: array([   12, 32787,    27, ..., 32722, 32729, 32739], dtype=int32),
#  7: array([32771,     7,    11, ..., 32752, 32757, 32764], dtype=int32),
#  8: array([    2,     5, 32775, ..., 32732, 32736, 32741], dtype=int32),
#  9: array([    4,    21,    24, ..., 32735, 32758, 32765], dtype=int32),
#  10: array([32768,     3, 32772, ..., 32749, 32755, 32762], dtype=int32)}

# %%
start_time = time.time()

for subset in range(1, N+1):
    submodel_dict[(subset,)] = copy.deepcopy(global_model)
    submodel_dict[(subset,)].to(device)
    submodel_dict[(subset,)].train() 
 
train_loss, train_accuracy = [], []
val_acc_list, net_list = [], []
print_every = 1

idxs_users = np.arange(1, N+1)
total_data = sum(len(user_groups[i]) for i in range(1, N+1))
fraction = [len(user_groups[i])/total_data for i in range(1, N+1)]

for epoch in tqdm(range(EPOCHS)):
    local_weights, local_losses = [], []
    print(f'\n | Global Training Round : {epoch+1} |\n')
    global_model.train()
    for idx in idxs_users:
        trainloader = DataLoader(train_datasets[idx], batch_size=local_bs, shuffle=True)
        local_model = LocalUpdate(lr, local_ep, trainloader)
        w, loss = local_model.update_weights(model=copy.deepcopy(global_model))
        local_weights.append(copy.deepcopy(w))
        local_losses.append(copy.deepcopy(loss))
    global_weights = average_weights(local_weights, fraction) 
    loss_avg = sum(local_losses) / len(local_losses)
    train_loss.append(loss_avg)

    gradients = calculate_gradients(local_weights, global_model.state_dict()) 
    for i in range(1, N+1):
        subset_weights = update_weights_from_gradients(gradients[i-1], submodel_dict[(i,)].state_dict()) 
        subset_weights = fixfuckingbn(subset_weights, global_model.state_dict())
        submodel_dict[(i,)].load_state_dict(subset_weights)

    global_model.load_state_dict(global_weights)
    global_model.eval()

    if (epoch+1) % print_every == 0:
        print(f' \nAvg Training Stats after {epoch+1} global rounds:')
        print(f'Training Loss : {np.mean(np.array(train_loss))}')
        # print('Train Accuracy: {:.2f}% \n'.format(100*train_accuracy[-1]))

test_acc, test_loss = test_inference(global_model, test_dataset)
print(f' \n Results after {EPOCHS} global rounds of training:')
print("|---- Test Accuracy: {:.2f}%".format(100*test_acc))

accuracy_dict[powerset[-1]] = test_acc

# ADJUSTED-OR APPROX
for subset in powerset[:-1]: 
    if len(subset) > 1:
        # calculate the average of the subset of weights from list of all the weights
        subset_weights = average_weights([submodel_dict[(i,)].state_dict() for i in subset], [fraction[i-1] for i in subset]) 
        submodel = copy.deepcopy(submodel_dict[()])
        submodel.load_state_dict(subset_weights)
        
        test_acc, test_loss = test_inference(submodel,test_dataset)
        print(f' \n Results after {EPOCHS} global rounds of training (for OR): ')
        print("|---- Test Accuracy for {}: {:.2f}%".format(subset, 100*test_acc))
        accuracy_dict[subset] = test_acc
    else: 
        test_acc, test_loss = test_inference(submodel_dict[subset], test_dataset)
        accuracy_dict[subset] = test_acc

trainTime = time.time() - start_time
start_time = time.time()
shapley_dict = shapley(accuracy_dict, N)
shapTime = time.time() - start_time
start_time = time.time()
lc_dict = least_core(accuracy_dict, N)
LCTime = time.time() - start_time
totalShapTime = trainTime + shapTime
totalLCTime = trainTime + LCTime
print(f'\n ACCURACY: {accuracy_dict[powerset[-1]]}')
print('\n Total Time Shapley: {0:0.4f}'.format(totalShapTime))
print('\n Total Time LC: {0:0.4f}'.format(totalLCTime))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  | Global Training Round : 1 |
#  20%|██        | 1/5 [02:06<08:26, 126.61s/it]
#
# Avg Training Stats after 1 global rounds:
# Training Loss : 2.0541287753582003
#
#  | Global Training Round : 2 |
#  40%|████      | 2/5 [04:13<06:19, 126.62s/it]
#
# Avg Training Stats after 2 global rounds:
# Training Loss : 2.016412021398544
#
#  | Global Training Round : 3 |
#  60%|██████    | 3/5 [06:20<04:13, 126.80s/it]
#
# Avg Training Stats after 3 global rounds:
# Training Loss : 1.9729186907609302
#
#  | Global Training Round : 4 |
#  80%|████████  | 4/5 [08:27<02:06, 126.86s/it]
#
# Avg Training Stats after 4 global rounds:
# Training Loss : 1.9333354570567605
#
#  | Global Training Round : 5 |
# 100%|██████████| 5/5 [10:34<00:00, 126.95s/it]
#
# Avg Training Stats after 5 global rounds:
# Training Loss : 1.89786670691967
#
#  Results after 5 global rounds of training:
# |---- Test Accuracy: 62.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2): 44.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3): 45.56%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4): 46.28%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5): 44.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6): 44.29%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 7): 39.96%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 8): 39.09%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 9): 19.60%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 10): 8.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3): 43.48%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4): 46.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5): 41.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6): 47.66%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 7): 41.25%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 8): 37.03%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 9): 17.66%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 10): 11.20%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4): 44.08%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5): 44.77%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6): 49.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 7): 40.39%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 8): 37.09%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 9): 21.92%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 10): 8.62%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5): 45.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6): 48.10%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 7): 41.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 8): 36.86%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 9): 20.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 10): 8.94%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6): 42.29%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 7): 39.36%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 8): 31.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 9): 19.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 10): 9.15%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 7): 36.12%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 8): 31.99%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 9): 17.29%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 10): 10.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (7, 8): 20.65%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (7, 9): 10.69%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (7, 10): 5.68%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (8, 9): 14.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (8, 10): 7.58%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (9, 10): 7.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3): 47.72%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4): 48.84%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5): 50.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6): 51.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 7): 47.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 8): 45.73%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 9): 34.09%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 10): 14.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4): 49.46%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5): 52.03%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6): 52.92%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 7): 45.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 8): 46.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 9): 36.16%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 10): 18.13%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5): 52.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 6): 53.19%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 7): 48.49%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 8): 48.79%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 9): 34.28%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 10): 16.41%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 6): 49.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 7): 51.44%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 8): 45.66%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 9): 35.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 10): 13.93%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 7): 47.87%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 8): 45.26%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 9): 32.77%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 10): 13.75%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 7, 8): 44.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 7, 9): 27.86%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 7, 10): 10.21%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 8, 9): 26.68%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 8, 10): 12.59%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 9, 10): 13.68%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4): 48.64%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5): 50.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 6): 53.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 7): 47.60%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 8): 44.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 9): 35.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 10): 17.16%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5): 51.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 6): 52.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 7): 48.36%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 8): 47.84%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 9): 33.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 10): 17.65%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 6): 50.96%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 7): 51.42%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 8): 43.15%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 9): 32.60%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 10): 14.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 7): 48.90%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 8): 43.02%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 9): 29.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 10): 16.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 7, 8): 43.79%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 7, 9): 26.07%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 7, 10): 14.60%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 8, 9): 24.94%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 8, 10): 12.63%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 9, 10): 10.73%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5): 51.58%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 6): 53.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 7): 46.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 8): 46.84%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 9): 35.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 10): 15.71%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 6): 53.93%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 7): 50.60%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 8): 45.86%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 9): 32.84%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 10): 14.44%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 7): 48.41%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 8): 44.57%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 9): 32.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 10): 14.22%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 7, 8): 43.94%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 7, 9): 26.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 7, 10): 10.69%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 8, 9): 23.54%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 8, 10): 14.06%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 9, 10): 10.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 6): 52.23%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 7): 49.71%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 8): 44.89%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 9): 29.09%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 10): 12.17%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 7): 48.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 8): 43.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 9): 30.15%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 10): 13.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 7, 8): 44.20%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 7, 9): 23.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 7, 10): 6.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 8, 9): 21.14%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 8, 10): 9.69%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 9, 10): 8.83%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 7): 48.17%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 8): 41.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 9): 30.07%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 10): 11.63%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 7, 8): 36.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 7, 9): 18.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 7, 10): 6.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 8, 9): 18.72%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 8, 10): 9.41%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 9, 10): 7.45%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 7, 8): 38.54%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 7, 9): 23.15%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 7, 10): 9.75%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 8, 9): 21.77%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 8, 10): 9.30%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 9, 10): 8.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (7, 8, 9): 12.54%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (7, 8, 10): 7.26%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (7, 9, 10): 5.27%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (8, 9, 10): 7.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4): 50.50%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5): 52.84%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 6): 53.50%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 7): 50.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 8): 49.67%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 9): 46.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 10): 32.78%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5): 53.79%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6): 54.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 7): 51.11%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 8): 53.05%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 9): 47.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 10): 30.22%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6): 53.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 7): 54.07%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 8): 50.14%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 9): 48.39%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 10): 26.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 7): 53.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 8): 50.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 9): 47.14%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 10): 27.69%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 7, 8): 52.05%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 7, 9): 43.98%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 7, 10): 23.26%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 8, 9): 41.11%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 8, 10): 22.24%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 9, 10): 15.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5): 54.69%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6): 55.84%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 7): 50.02%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 8): 51.78%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 9): 48.25%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 10): 34.64%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6): 55.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 7): 53.55%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 8): 51.28%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 9): 48.44%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 10): 31.11%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 7): 53.57%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 8): 51.55%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 9): 46.45%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 10): 29.32%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 7, 8): 50.49%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 7, 9): 42.73%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 7, 10): 26.46%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 8, 9): 41.90%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 8, 10): 24.65%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 9, 10): 19.45%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 6): 55.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 7): 54.30%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 8): 51.69%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 9): 47.10%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 10): 30.17%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 6, 7): 54.20%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 6, 8): 52.42%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 6, 9): 46.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 6, 10): 26.77%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 7, 8): 53.72%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 7, 9): 43.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 7, 10): 22.59%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 8, 9): 40.09%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 8, 10): 22.76%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 9, 10): 18.44%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 6, 7): 53.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 6, 8): 49.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 6, 9): 46.15%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 6, 10): 25.65%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 7, 8): 51.21%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 7, 9): 42.41%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 7, 10): 23.16%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 8, 9): 39.45%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 8, 10): 21.58%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 9, 10): 17.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 7, 8): 48.95%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 7, 9): 40.87%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 7, 10): 22.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 8, 9): 38.71%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 8, 10): 18.44%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 6, 9, 10): 14.77%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 7, 8, 9): 36.22%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 7, 8, 10): 16.29%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 7, 9, 10): 14.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 8, 9, 10): 15.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5): 53.97%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 6): 55.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 7): 50.57%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 8): 51.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 9): 46.57%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 10): 33.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 6): 56.28%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 7): 53.86%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 8): 50.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 9): 47.05%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 10): 29.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 6, 7): 53.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 6, 8): 49.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 6, 9): 45.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 6, 10): 27.65%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 7, 8): 49.68%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 7, 9): 41.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 7, 10): 25.16%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 8, 9): 41.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 8, 10): 22.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 9, 10): 13.36%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 6): 55.17%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 7): 53.84%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 8): 50.33%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 9): 45.62%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 10): 28.76%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 6, 7): 53.17%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 6, 8): 51.22%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 6, 9): 45.15%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 6, 10): 26.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 7, 8): 52.60%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 7, 9): 42.89%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 7, 10): 22.92%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 8, 9): 40.53%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 8, 10): 22.25%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 9, 10): 14.76%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 6, 7): 54.12%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 6, 8): 47.39%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 6, 9): 46.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 6, 10): 25.62%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 7, 8): 50.19%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 7, 9): 41.87%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 7, 10): 23.62%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 8, 9): 39.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 8, 10): 19.94%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 9, 10): 13.17%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 7, 8): 47.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 7, 9): 38.97%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 7, 10): 22.09%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 8, 9): 38.57%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 8, 10): 17.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 6, 9, 10): 14.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 7, 8, 9): 36.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 7, 8, 10): 17.28%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 7, 9, 10): 14.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 8, 9, 10): 12.37%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 6): 56.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 7): 52.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 8): 51.64%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 9): 45.65%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 10): 30.64%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 6, 7): 53.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 6, 8): 50.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 6, 9): 44.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 6, 10): 25.63%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 7, 8): 51.46%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 7, 9): 40.27%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 7, 10): 21.73%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 8, 9): 38.97%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 8, 10): 21.62%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 9, 10): 14.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 6, 7): 54.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 6, 8): 49.49%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 6, 9): 44.24%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 6, 10): 26.08%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 7, 8): 50.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 7, 9): 38.02%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 7, 10): 21.67%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 8, 9): 36.02%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 8, 10): 18.69%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 9, 10): 14.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 7, 8): 47.66%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 7, 9): 36.65%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 7, 10): 22.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 8, 9): 39.05%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 8, 10): 19.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 6, 9, 10): 12.64%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 7, 8, 9): 32.56%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 7, 8, 10): 14.13%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 7, 9, 10): 11.81%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 8, 9, 10): 14.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 6, 7): 53.14%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 6, 8): 48.52%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 6, 9): 43.17%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 6, 10): 22.37%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 7, 8): 50.88%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 7, 9): 36.22%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 7, 10): 16.16%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 8, 9): 32.81%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 8, 10): 14.72%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 9, 10): 10.92%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 7, 8): 48.59%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 7, 9): 38.28%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 7, 10): 19.05%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 8, 9): 36.73%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 8, 10): 16.52%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 6, 9, 10): 11.73%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 7, 8, 9): 27.90%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 7, 8, 10): 7.76%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 7, 9, 10): 7.41%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 8, 9, 10): 9.88%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 7, 8): 46.11%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 7, 9): 35.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 7, 10): 16.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 8, 9): 32.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 8, 10): 13.24%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 6, 9, 10): 11.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 7, 8, 9): 19.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 7, 8, 10): 8.48%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 7, 9, 10): 5.46%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (5, 8, 9, 10): 5.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 7, 8, 9): 27.32%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 7, 8, 10): 10.29%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 7, 9, 10): 5.86%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (6, 8, 9, 10): 8.95%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (7, 8, 9, 10): 6.08%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5): 54.88%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 6): 55.59%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 7): 52.66%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 8): 53.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 9): 53.71%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 10): 47.99%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 6): 56.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 7): 55.42%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 8): 53.46%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 9): 54.77%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 10): 44.52%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 6, 7): 55.64%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 6, 8): 53.83%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 6, 9): 54.82%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 6, 10): 44.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 7, 8): 53.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 7, 9): 51.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 7, 10): 43.13%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 8, 9): 53.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 8, 10): 39.48%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 9, 10): 26.24%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6): 56.35%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 7): 55.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 8): 54.79%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 9): 55.93%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 10): 44.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 7): 55.21%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 8): 55.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 9): 55.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 10): 42.20%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 7, 8): 55.94%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 7, 9): 53.10%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 7, 10): 40.30%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 8, 9): 53.26%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 8, 10): 37.32%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 9, 10): 25.55%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 7): 56.12%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 8): 52.44%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 9): 55.54%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 10): 40.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 7, 8): 55.05%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 7, 9): 53.52%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 7, 10): 38.44%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 8, 9): 52.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 8, 10): 37.71%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 9, 10): 24.29%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 7, 8): 53.53%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 7, 9): 50.35%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 7, 10): 38.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 8, 9): 51.48%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 8, 10): 34.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 9, 10): 22.54%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 7, 8, 9): 50.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 7, 8, 10): 33.32%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 7, 9, 10): 21.19%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 8, 9, 10): 18.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6): 58.02%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 7): 55.06%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 8): 54.59%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 9): 55.21%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 10): 48.07%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 7): 55.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 8): 55.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 9): 54.81%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 10): 44.16%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 7, 8): 54.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 7, 9): 51.22%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 7, 10): 42.46%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 8, 9): 52.72%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 8, 10): 38.75%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 9, 10): 28.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 7): 56.82%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 8): 53.97%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 9): 54.82%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 10): 43.33%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 7, 8): 54.21%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 7, 9): 52.12%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 7, 10): 42.24%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 8, 9): 52.86%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 8, 10): 40.42%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 9, 10): 29.52%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 7, 8): 53.39%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 7, 9): 49.45%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 7, 10): 41.20%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 8, 9): 51.54%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 8, 10): 35.76%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 9, 10): 26.10%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 7, 8, 9): 49.10%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 7, 8, 10): 34.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 7, 9, 10): 23.05%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 8, 9, 10): 23.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 6, 7): 56.62%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 6, 8): 53.92%
#
# ...
# |---- Test Accuracy for (1, 2, 3, 7, 8, 9, 10): 42.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 8): 58.27%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 9): 60.68%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 10): 59.78%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 8, 9): 62.41%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 8, 10): 53.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 9, 10): 47.60%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 7, 8, 9): 61.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 7, 8, 10): 54.58%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 7, 9, 10): 44.56%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 8, 9, 10): 44.14%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 7, 8, 9): 61.06%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 7, 8, 10): 52.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 7, 9, 10): 43.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 8, 9, 10): 42.84%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 7, 8, 9, 10): 39.92%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 7, 8, 9): 59.94%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 7, 8, 10): 52.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 7, 9, 10): 43.94%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 8, 9, 10): 43.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 7, 8, 9, 10): 41.27%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 6, 7, 8, 9, 10): 39.05%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 8): 58.32%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 9): 59.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 10): 60.92%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 8, 9): 61.59%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 8, 10): 54.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 9, 10): 49.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 7, 8, 9): 60.92%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 7, 8, 10): 55.76%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 7, 9, 10): 46.45%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 8, 9, 10): 45.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 7, 8, 9): 60.36%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 7, 8, 10): 52.75%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 7, 9, 10): 43.59%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 8, 9, 10): 44.30%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 7, 8, 9, 10): 40.57%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 7, 8, 9): 59.56%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 7, 8, 10): 54.12%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 7, 9, 10): 45.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 8, 9, 10): 45.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 7, 8, 9, 10): 41.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 6, 7, 8, 9, 10): 39.54%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 6, 7, 8, 9): 58.75%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 6, 7, 8, 10): 51.93%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 6, 7, 9, 10): 42.92%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 6, 8, 9, 10): 42.33%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 7, 8, 9, 10): 39.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 6, 7, 8, 9, 10): 36.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 5, 6, 7, 8, 9, 10): 38.13%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 8): 57.46%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 9): 59.25%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 10): 59.17%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 8, 9): 61.96%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 8, 10): 53.36%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 9, 10): 47.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 7, 8, 9): 60.54%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 7, 8, 10): 54.20%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 7, 9, 10): 44.89%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 8, 9, 10): 44.34%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 6, 7, 8, 9): 60.12%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 6, 7, 8, 10): 51.12%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 6, 7, 9, 10): 40.97%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 6, 8, 9, 10): 40.89%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 7, 8, 9, 10): 39.29%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 6, 7, 8, 9): 59.49%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 6, 7, 8, 10): 52.26%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 6, 7, 9, 10): 41.65%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 6, 8, 9, 10): 43.36%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 7, 8, 9, 10): 40.26%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 6, 7, 8, 9, 10): 36.88%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 6, 7, 8, 9): 58.87%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 6, 7, 8, 10): 50.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 6, 7, 9, 10): 40.78%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 6, 8, 9, 10): 39.85%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 7, 8, 9, 10): 37.76%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 6, 7, 8, 9, 10): 35.72%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 5, 6, 7, 8, 9, 10): 35.02%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 6, 7, 8, 9): 57.90%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 6, 7, 8, 10): 50.96%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 6, 7, 9, 10): 39.19%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 6, 8, 9, 10): 37.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 7, 8, 9, 10): 31.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 6, 7, 8, 9, 10): 33.36%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 5, 6, 7, 8, 9, 10): 28.60%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (4, 5, 6, 7, 8, 9, 10): 21.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 7, 8): 59.28%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 7, 9): 61.78%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 7, 10): 64.51%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 8, 9): 64.29%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 8, 10): 60.11%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 9, 10): 57.03%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 7, 8, 9): 63.75%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 7, 8, 10): 61.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 7, 9, 10): 55.03%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 8, 9, 10): 55.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 6, 7, 8, 9): 63.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 6, 7, 8, 10): 59.32%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 6, 7, 9, 10): 54.21%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 6, 8, 9, 10): 53.80%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 7, 8, 9, 10): 52.35%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 6, 7, 8, 9): 63.19%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 6, 7, 8, 10): 59.96%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 6, 7, 9, 10): 54.42%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 6, 8, 9, 10): 54.31%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 7, 8, 9, 10): 53.14%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 6, 7, 8, 9, 10): 50.91%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 8, 9): 63.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 8, 10): 58.06%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 9, 10): 53.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 8, 9, 10): 51.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 7, 8, 9, 10): 50.38%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 6, 7, 8, 9, 10): 48.59%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 5, 6, 7, 8, 9, 10): 49.08%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 8, 9): 62.70%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 8, 10): 59.03%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 9, 10): 53.61%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 8, 9, 10): 53.66%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 7, 8, 9, 10): 51.50%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 6, 7, 8, 9, 10): 49.04%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 5, 6, 7, 8, 9, 10): 50.13%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 4, 5, 6, 7, 8, 9, 10): 47.40%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 8, 9): 62.79%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 8, 10): 57.56%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 9, 10): 52.24%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 8, 9, 10): 51.18%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 7, 8, 9, 10): 50.12%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 6, 7, 8, 9, 10): 46.74%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 5, 6, 7, 8, 9, 10): 48.41%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 4, 5, 6, 7, 8, 9, 10): 46.00%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (3, 4, 5, 6, 7, 8, 9, 10): 42.99%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 7, 8, 9): 64.47%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 7, 8, 10): 63.43%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 7, 9, 10): 60.67%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 6, 8, 9, 10): 60.01%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 5, 7, 8, 9, 10): 59.66%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 4, 6, 7, 8, 9, 10): 58.21%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 3, 5, 6, 7, 8, 9, 10): 58.19%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 2, 4, 5, 6, 7, 8, 9, 10): 56.19%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (1, 3, 4, 5, 6, 7, 8, 9, 10): 56.88%
#
#  Results after 5 global rounds of training (for OR):
# |---- Test Accuracy for (2, 3, 4, 5, 6, 7, 8, 9, 10): 55.19%
# status: 1, Optimal
# objective: 0.290775
# e: 0.291
# x(1): 0.1
# x(10): 0.0
# x(2): 0.091
# x(3): 0.108
# x(4): 0.101
# x(5): 0.076
# x(6): 0.095
# x(7): 0.056
# x(8): 0.0
# x(9): 0.0
#
#  ACCURACY: 0.627
#
#  Total Time Shapley: 4186.7075
#
#  Total Time LC: 4186.7703

# %%
def stats(vector):
    n = len(vector)
    egal = np.array([1/n for i in range(n)])
    normalised = np.array(vector / vector.sum())
    msg = f'Original vector: {vector}\n'
    msg += f'Normalised vector: {normalised}\n'
    msg += f'Max Dif: {normalised.max()-normalised.min()}\n'
    msg += f'Distance: {np.linalg.norm(normalised-egal)}\n'

    msg += f'Budget: {vector.sum()}\n'
    print(msg)

# %%
stats(np.array(list(shapley_dict.values())))
# Out:
# Original vector: [ 0.12156075  0.10917627  0.10981044  0.10419635  0.07705849  0.07902048
#   0.04776313  0.03351619 -0.03449246 -0.12100964]
# Normalised vector: [ 0.23084078  0.20732296  0.20852722  0.19786622  0.14633212  0.15005787
#   0.09070098  0.06364639 -0.0655003  -0.22979423]
# Max Dif: 0.4606350110622801
# Distance: 0.4384159898612196
# Budget: 0.5266

# %%
stats(np.array([i.value() for i in lc_dict.variables()])[1:])
# Out:
# Original vector: [0.100125 0.       0.091025 0.107525 0.101125 0.0763   0.0948   0.0561
#  0.       0.      ]
# Normalised vector: [0.159689   0.         0.14517544 0.17149123 0.16128389 0.12169059
#  0.15119617 0.08947368 0.         0.        ]
# Max Dif: 0.17149122807017544
# Distance: 0.21834065249685256
# Budget: 0.627
